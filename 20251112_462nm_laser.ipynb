# %%
#462nm laser Current-Power
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MultipleLocator
import math

#LiRb style
plt.style.use('lirb')

I=np.array([
233,
254,
281,
303,
339,
364,
391,
420,
440,
462,
498,
522,
546,
568,
599,
637,
674,
701,
721,
756,
773,
795,
827,
865,
891,
926,
957,
986,
1030,
1065,
1094,
1134,
1161,
1214,
1279,
1331,
1400,
1534,
1687,
1757
])/1000

P=np.array([
9.00E-03,
6.20E-02,
1.32E-01,
1.97E-01,
3.05E-01,
3.80E-01,
4.51E-01,
5.25E-01,
5.79E-01,
6.34E-01,
7.25E-01,
7.84E-01,
8.46E-01,
9.01E-01,
9.76E-01,
1.07E+00,
1.15E+00,
1.21E+00,
1.25E+00,
1.33E+00,
1.36E+00,
1.40E+00,
1.46E+00,
1.54E+00,
1.58E+00,
1.64E+00,
1.70E+00,
1.75E+00,
1.82E+00,
1.87E+00,
1.91E+00,
1.97E+00,
2.01E+00,
2.08E+00,
2.16E+00,
2.22E+00,
2.30E+00,
2.42E+00,
2.51E+00,
2.55E+00,
])


I_calibrate=np.array([
305,
425,
498,
600,
803,
862,
1026,
1140,
1348
])*10**(-3)

P_calibrate=np.array([
0.191,
0.525,
0.703,
0.951,
1.385,
1.492,
1.77,
1.94,
2.2
])

# %%
plt.plot(I,P,label='20251112 calibration')
plt.scatter(I_calibrate,P_calibrate,color='C1',marker='+',label='20251117 re-calibration')
plt.xlabel('I/A')
plt.ylabel('P/W')
#plt.scatter(I,P)
plt.xlim(0,2)
plt.ylim(0,3)
plt.title('462 nm laser I-P')
plt.legend()
plt.savefig('20251112_462nm_laser')

# %%
462e-9/(np.pi*0.3e-3)/np.pi*180
# Out:
# 0.02808623210565603
